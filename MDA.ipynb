# %% [markdown]
# <h4>Código realizado con el fin de limpiar y unir archivos .csv del CENACE</>

# %%
import pandas as pd #Importamos a Pandas

# %%
# Crea una lista con las rutas de los archivos
ano=2025
sistema='SIN'
meses=['Ene','Feb','Mar','Abr','May','Jun','Jul','Ago','Sep','Oct','Nov','Dic']
rutas=[]
for i,mes in enumerate(meses):
	i=i+2
	for j in range(1,3):
		if(i>9):
			name=f'PreciosMargLocales SIN MDA Mes {mes}0{j} v{ano} {i} 03_08 00 01.csv'
		else:
			name=f'PreciosMargLocales SIN MDA Mes {mes}0{j} v{ano} 0{i} 03_08 00 01.csv'
		rutas.append(name)
print(rutas)
# Out:
# ['PreciosMargLocales SIN MDA Mes Ene01 v2025 02 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Ene02 v2025 02 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Feb01 v2025 03 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Feb02 v2025 03 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Mar01 v2025 04 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Mar02 v2025 04 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Abr01 v2025 05 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Abr02 v2025 05 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes May01 v2025 06 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes May02 v2025 06 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Jun01 v2025 07 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Jun02 v2025 07 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Jul01 v2025 08 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Jul02 v2025 08 03_08 00 01.csv', 'PreciosMargLocales SIN MDA Mes Ago01 v2025 09 03_08 00 01.csv', 'PreciosMargLocales SI
# ...

# %%
# Escribir las fechas de publicación del catálogo de Nodos con el siguiente formato: AAAA-MM-DD
ano2025=['2025-01-21','2025-02-19','2025-03-21','2025-04-17','2025-05-27','2025-06-18','2025-07-31','2025-08-20','2025-09-26','2025-10-17','2025-11-15']
ano2024=['2024-01-24','2024-02-20','2024-03-22','2024-04-25','2024-05-18','2024-06-26','2024-07-21','2024-08-29','2024-09-21','2024-10-18','2024-11-20','2024-12-17']
ano2026=['2026-01-24']
#fecha_atras<fecha<=fecha_adelante
# Se toma el catálogo cuya Fecha de actualización sea la más reciente antes del inicio del periodo de liquidación
#Hacer un filtro que seleccione el rango de fechas seleccionado y depués guardar
# fecha_ini=0
# fecha_fin=0
fechas_ini=[]
fechas_fin=[]
for i in range(0,12):
	if i==0:
		fecha_ini=ano2024[11]
		fecha_fin=ano2025[i]
		fechas_ini.append(fecha_ini)
		fechas_fin.append(fecha_fin)
	# Variar dependiendo el número de fechas que tenemos disponibles
	elif i==11:
		try:
			fecha_ini=ano2025[i]
			fecha_fin=ano2026[0]
			fechas_ini.append(fecha_ini)
			fechas_fin.append(fecha_fin)
		except:
			print("Aún no hay suficientes")
	else:
		try:
			fecha_ini=ano2025[i-1]
			fecha_fin=ano2025[i]
			fechas_ini.append(fecha_ini)
			fechas_fin.append(fecha_fin)
		except:
			print("Aún no hay suficientes")
print(fechas_ini)
print(fechas_fin)
	#Cocatenar todos los CSV
# Out:
# Aún no hay suficientes
# ['2024-12-17', '2025-01-21', '2025-02-19', '2025-03-21', '2025-04-17', '2025-05-27', '2025-06-18', '2025-07-31', '2025-08-20', '2025-09-26', '2025-10-17']
# ['2025-01-21', '2025-02-19', '2025-03-21', '2025-04-17', '2025-05-27', '2025-06-18', '2025-07-31', '2025-08-20', '2025-09-26', '2025-10-17', '2025-11-15']

# %%
try:
	# Enero
	# Ruta Windows
	df_1=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[0]}',skiprows=7)
	df_2=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[1]}',skiprows=7)
	#Ruta Linux
	# df_1=pd.read_csv(f'/home/santiago/Documentos/CIC/Datos/Por Nodo/{ano}/MDA/{rutas[0]}',skiprows=7)
	# df_2=pd.read_csv(f'/home/santiago/Documentos/CIC/Datos/Por Nodo/{ano}/MDA/{rutas[1]}',skiprows=7)
	df_enero=pd.concat([df_1,df_2], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_enero.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[0]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Enero aún no están")
try:
	#Febrero
	df_3=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[2]}',skiprows=7)
	df_4=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[3]}',skiprows=7)
	df_febrero=pd.concat([df_3,df_4], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_febrero.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[1]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Febrero aún no están")
try:
	#Marzo
	df_5=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[4]}',skiprows=7)
	df_6=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[5]}',skiprows=7)
	df_marzo=pd.concat([df_5,df_6], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_marzo.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[2]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Marzo aún no están")
try:
	# Abril
	df_7=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[6]}',skiprows=7)
	df_8=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[7]}',skiprows=7)
	df_abril=pd.concat([df_7,df_8], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_abril.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[3]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Abril aún no están")
try:
	# Mayo
	df_9=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[8]}',skiprows=7)
	df_10=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[9]}',skiprows=7)
	df_mayo=pd.concat([df_9,df_10], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_mayo.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[4]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Mayo aún no están")
try:
	# Junio
	df_11=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[10]}',skiprows=7)
	df_12=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[11]}',skiprows=7)
	df_junio=pd.concat([df_11,df_12], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_junio.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[5]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Junio aún no están")
try:
	# Julio
	df_13=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[12]}',skiprows=7)
	df_14=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[13]}',skiprows=7)
	df_julio=pd.concat([df_13,df_14], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_julio.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[6]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Julio aún no están")
try:
	# Agosto
	df_15=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[14]}',skiprows=7)
	df_16=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[15]}',skiprows=7)
	df_agosto=pd.concat([df_15,df_16], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_agosto.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[7]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Agosto aún no están")
try:
	# Septiembre
	df_17=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[16]}',skiprows=7)
	df_18=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[17]}',skiprows=7)
	df_septiembre=pd.concat([df_17,df_18], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_septiembre.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[8]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Septiembre aún no están")
try:
	# Octubre
	df_19=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[18]}',skiprows=7)
	df_20=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[19]}',skiprows=7)
	df_octubre=pd.concat([df_19,df_20], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_octubre.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[9]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Octubre aún no están")
try:
	# Noviembre
	df_21=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[20]}',skiprows=7)
	df_22=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[21]}',skiprows=7)
	df_noviembre=pd.concat([df_21,df_22], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_noviembre.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[10]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Noviembre aún no están")
try:
	# Diciembre
	df_23=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[22]}',skiprows=7)
	df_24=pd.read_csv(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Por Nodo/{sistema}/MDA/{ano}/{rutas[23]}',skiprows=7)
	df_diciembre=pd.concat([df_23,df_24], axis='rows') #Concatena los dos archivos por mes
	# Guardamos los DataFrames concatenados
	df_diciembre.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA Mes {meses[11]} v{ano}.csv', index=False, encoding='utf-8')
except:
	print("Los archivos de Diciembre aún no están")

# %%
#Concatena todos los archivos limpios por mes
#Colocar los archivos que ya tienen DataFrame
df_completo=pd.concat([df_enero,df_febrero,df_abril,df_mayo,df_junio,df_julio,df_marzo,df_agosto,df_septiembre,df_octubre,df_noviembre,df_diciembre], axis='rows') #Concatena los dos archivos por mes
# Guardamos el DataFrame completo
df_completo.to_csv(f'./Datos_limpios/MDA/{ano}/Completos/PreciosMargLocales {sistema} MDA v{ano}.csv', index=False, encoding='utf-8')

# %%
df_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21270936 entries, 0 to 932351
# Data columns (total 7 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   Fecha                              object
#  1    Hora                              int64
#  2    Clave del nodo                    object
#  3    Precio marginal local ($/MWh)     float64
#  4    Componente de energia ($/MWh)     float64
#  5    Componente de perdidas ($/MWh)    float64
#  6    Componente de congestion ($/MWh)  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.3+ GB

# %%
# Dividir los datos de acuerdo al Catálogo de Nodos
df_2025=pd.read_csv(f'./Datos_limpios/MDA/2025/Completos/PreciosMargLocales SIN MDA v2025.csv')
df_2024=pd.read_csv(f'./Datos_limpios/MDA/2024/Completos/PreciosMargLocales SIN MDA v2024.csv')
# Unimos ambos años
df_union = pd.concat([df_2024, df_2025], ignore_index=True)
df_union['Fecha'] = pd.to_datetime(df_union['Fecha'])

# %%
# Definimos fechas límite
for i,_ in enumerate(fechas_ini):
	fecha_inicio = pd.Timestamp(f'{fechas_ini[i]}')
	fecha_fin = pd.Timestamp(f'{fechas_fin[i]}')
	df_catalogo=df_union.query("Fecha > @fecha_inicio and Fecha <= @fecha_fin")
	print(fecha_inicio)
	print(fecha_fin)
	# Guardamos el DataFrame
	df_catalogo.to_csv(f'./Datos_limpios/MDA/{ano}/Catálogo_de_Nodos/PreciosMargLocales {sistema} MDA {fechas_ini[i]} {fechas_fin[i]}.csv', index=False, encoding='utf-8')
# Out:
# 2024-12-17 00:00:00
# 2025-01-21 00:00:00
# 2025-01-21 00:00:00
# 2025-02-19 00:00:00
# 2025-02-19 00:00:00
# 2025-03-21 00:00:00
# 2025-03-21 00:00:00
# 2025-04-17 00:00:00
# 2025-04-17 00:00:00
# 2025-05-27 00:00:00
# 2025-05-27 00:00:00
# 2025-06-18 00:00:00
# 2025-06-18 00:00:00
# 2025-07-31 00:00:00
# 2025-07-31 00:00:00
# 2025-08-20 00:00:00
# 2025-08-20 00:00:00
# 2025-09-26 00:00:00
# 2025-09-26 00:00:00
# 2025-10-17 00:00:00
# 2025-10-17 00:00:00
# 2025-11-15 00:00:00

# %%
df_primero=pd.read_csv('./Datos_limpios/MDA/2025/Catálogo_de_Nodos/PreciosMargLocales SIN MDA 2025-10-17 2025-11-15.csv')
df_primero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819168 entries, 0 to 819167
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha                              819168 non-null  object
#  1    Hora                              819168 non-null  int64
#  2    Clave del nodo                    819168 non-null  object
#  3    Precio marginal local ($/MWh)     819168 non-null  float64
#  4    Componente de energia ($/MWh)     819168 non-null  float64
#  5    Componente de perdidas ($/MWh)    819168 non-null  float64
#  6    Componente de congestion ($/MWh)  819168 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 43.7+ MB
