# %% [markdown]
# <h4>Algoritmo realizando con el fin de limpiar los archivos .csv de Catálogos de Nodos P</>

# %%
import pandas as pd #Importamos a Pandas

# %%
ano=2025
# Escribir las fechas de publicación del catálogo de Nodos con el siguiente formato: AAAA-MM-DD
ano2025=['2025-01-21','2025-02-19','2025-03-21','2025-04-17','2025-05-27','2025-06-18','2025-07-31','2025-08-20','2025-09-26','2025-10-17','2025-11-15']
ano2024=['2024-01-24','2024-02-20','2024-03-22','2024-04-25','2024-05-18','2024-06-26','2024-07-21','2024-08-29','2024-09-21','2024-10-18','2024-11-20','2024-12-17']
ano2026=['2026-01-24']

# %%
for fecha in ano2024:
	df=pd.read_excel(f'C:/Users/Santi/OneDrive - Instituto Politecnico Nacional/Documents/CIC/Datos/Catálogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{fecha}).xlsx',skiprows=1)
	df.to_excel(f'./Datos_limpios/Catálogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{fecha}).xlsx', index=False)

# %%
df_prueba=pd.read_excel(f'./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-01-21).xlsx')
df_prueba.head()

# %%
# Unir las filas de los catálogos y eliminar las repetidas
# df1=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-01-21).xlsx')
# df2=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-02-19).xlsx')
# df3=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-03-21).xlsx')
# df4=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-04-17).xlsx')
# df5=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-05-27).xlsx')
# df6=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-06-18).xlsx')
# df7=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-07-31).xlsx')
# df8=pd.read_excel('./Datos_limpios/Catálogos de NodosP/2025/Catálogo NodosP Sistema Eléctrico Nacional (v2025-08-20).xlsx')
dfs=[]
for fecha in ano2025:
	df=pd.read_excel(f'./Datos_limpios/Catálogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{fecha}).xlsx')
	dfs.append(df)

# Concatena los registros
df_completo=pd.concat(dfs,ignore_index=True)
# Elmina filas duplicadas por la Clave del Nodod
df_completo=df_completo.drop_duplicates()
df_completo.info()
df_completo.to_excel(f'./Datos_limpios/Catálogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{ano}).xlsx', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2624 entries, 0 to 27511
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SISTEMA                              2624 non-null   object
#  1   CENTRO DE CONTROL REGIONAL           2624 non-null   object
#  2   ZONA DE CARGA                        2624 non-null   object
#  3   CLAVE                                2624 non-null   object
#  4   NOMBRE                               2624 non-null   object
#  5   NIVEL DE TENSIÓN (kV)                2624 non-null   float64
#  6   DIRECTAMENTE MODELADA                2624 non-null   object
#  7   INDIRECTAMENTE MODELADA              2624 non-null   object
#  8   DIRECTAMENTE MODELADA.1              2624 non-null   object
#  9   INDIRECTAMENTE MODELADA.1            2624 non-null   object
#  10  ZONA DE OPERACIÓN DE TRANSMISIÓN     2624 non-null   object
# ...

# %%
print(f"Registros duplicados: {df_completo.duplicated().sum()}")
# Out:
# Registros duplicados: 0
