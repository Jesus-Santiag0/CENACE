# %% [markdown]
# <h4>Algoritmo realizando con el fin de limpiar los archivos .csv de Catálogos de Nodos P</>

# %%
from pathlib import Path
import pandas as pd

# %%
ano=2025
# Escribir las fechas de publicación del catálogo de Nodos con el siguiente formato: AAAA-MM-DD
ano2025=['2025-01-21','2025-02-19','2025-03-21','2025-04-17','2025-05-27','2025-06-18','2025-07-31','2025-08-20','2025-09-26','2025-10-17','2025-11-15','2025-12-13']
ano2024=['2024-01-24','2024-02-20','2024-03-22','2024-04-25','2024-05-18','2024-06-26','2024-07-21','2024-08-29','2024-09-21','2024-10-18','2024-11-20','2024-12-17']
ano2026=['2026-01-24']

# %%
directorio_origen = Path(f'G:/Datos/Catalogos de NodosP/{ano}')
directorio_origen = Path(f'G:/Datos/Catalogos de NodosP/{ano}')

# Ciclo for que recorre las fechas
# !Cambiar el año
for fecha in ano2025:
	# Busca el archivo que contiene esta fecha en su nombre
	archivos = list(directorio_origen.glob(f'*v{fecha}*.xlsx'))
	if archivos:
		ruta_origen = archivos[0]
		df = pd.read_excel(ruta_origen, skiprows=1)
		df.to_excel(f'G:/Datos_limpios/Catalogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{fecha}).xlsx', index=False)
		df.to_excel(f'G:/Datos_limpios/Catalogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{fecha}).xlsx', index=False)
		print(f"Procesado: {fecha}")
	else:
		print(f"No encontrado: {fecha}")
# Out:
# Procesado: 2025-01-21
# Procesado: 2025-02-19
# Procesado: 2025-03-21
# Procesado: 2025-04-17
# Procesado: 2025-05-27
# Procesado: 2025-06-18
# Procesado: 2025-07-31
# Procesado: 2025-08-20
# Procesado: 2025-09-26
# Procesado: 2025-10-17
# Procesado: 2025-11-15
# Procesado: 2025-12-13

# %%
# Crea una lista que contiene DataFrames
df_n=[]
directorio_procesado = Path(f'G:/Datos_limpios/Catalogos de NodosP/{ano}')

# !Cambiar el año
for fecha in ano2025:
	# Busca el archivo que contiene esta fecha en su nombre
	archivos = list(directorio_procesado.glob(f'*v{fecha}*.xlsx'))
	if archivos:
		df = pd.read_excel(archivos[0])
		df_n.append(df)

# Concatena los registros
df_completo=pd.concat(df_n,ignore_index=True)

# %%
df_completo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31031 entries, 0 to 31030
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SISTEMA                              31031 non-null  str
#  1   CENTRO DE CONTROL REGIONAL           31031 non-null  str
#  2   ZONA DE CARGA                        31031 non-null  str
#  3   CLAVE                                31031 non-null  str
#  4   NOMBRE                               31031 non-null  str
#  5   NIVEL DE TENSIÓN (kV)                31031 non-null  float64
#  6   DIRECTAMENTE MODELADA                31031 non-null  str
#  7   INDIRECTAMENTE MODELADA              31031 non-null  str
#  8   DIRECTAMENTE MODELADA.1              31031 non-null  str
#  9   INDIRECTAMENTE MODELADA.1            31031 non-null  str
#  10  ZONA DE OPERACIÓN DE TRANSMISIÓN     31031 non-null  str
# ...

# %%
# Elmina filas duplicadas por la Clave del Nodod
# df_completop=df_completo.drop_duplicates() #?2624
df_completop=df_completo.drop_duplicates(subset=['CLAVE','SISTEMA']) #? 2593
# ? Este cambio indica que 31 registros Cambiaron valores en algunas de sus columnas
df_completop.info()

df_completop.to_excel(f'G:/Datos_limpios/Catalogos de NodosP/{ano}/Catálogo NodosP Sistema Eléctrico Nacional (v{ano}).xlsx', index=False)
# Out:
# <class 'pandas.DataFrame'>
# Index: 2594 entries, 0 to 30928
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SISTEMA                              2594 non-null   str
#  1   CENTRO DE CONTROL REGIONAL           2594 non-null   str
#  2   ZONA DE CARGA                        2594 non-null   str
#  3   CLAVE                                2594 non-null   str
#  4   NOMBRE                               2594 non-null   str
#  5   NIVEL DE TENSIÓN (kV)                2594 non-null   float64
#  6   DIRECTAMENTE MODELADA                2594 non-null   str
#  7   INDIRECTAMENTE MODELADA              2594 non-null   str
#  8   DIRECTAMENTE MODELADA.1              2594 non-null   str
#  9   INDIRECTAMENTE MODELADA.1            2594 non-null   str
#  10  ZONA DE OPERACIÓN DE TRANSMISIÓN     2594 non-null   str
# ...

# %%
df_completop[df_completop["ENTIDAD FEDERATIVA (INEGI)"]=="No Aplica"]
# Out:
#     SISTEMA CENTRO DE CONTROL REGIONAL ZONA DE CARGA      CLAVE  \
# 114     BCA                  No Aplica     No Aplica  07IVY-230
# 115     BCA                  No Aplica     No Aplica  07OMS-230
# 408     SIN                  No Aplica     No Aplica  05ASC-115
# 409     SIN                  No Aplica     No Aplica  05DIA-115
# 410     SIN                  No Aplica     No Aplica  06EAP-138
# 411     SIN                  No Aplica     No Aplica  06LAA-138
# 412     SIN                  No Aplica     No Aplica  06RRD-138
# 413     SIN                  No Aplica     No Aplica  08BEL-115
# 414     SIN                  No Aplica     No Aplica  09LBR-230
#
#                NOMBRE  NIVEL DE TENSIÓN (kV)  DIRECTAMENTE MODELADA  \
# 114   Imperial Valley                  230.0  Directamente Modelada
# 115         Otay Mesa                  230.0  Directamente Modelada
# 408          Ascarate                  115.0  Directamente Modelada
# ...
